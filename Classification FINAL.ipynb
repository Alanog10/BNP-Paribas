# %% [markdown]
# # BNP Paribas- Bussines Case Project 2025/2026
# **CLASSIFICATION NOTEBOOK**
#
# **Group V**:
#    - Alano Gonçalves (20250457)
#    - Catarina Martins (20221914)
#    - João Carichas (20250507)
#    - Marta Ribeiro (20221886)
#    - Nicole Nogueira(20221961)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <a class="anchor" id="1. Import">    </a>
# # 1. Import
#
# </div>

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# ## 1.1 Import Libraries
#
# </a>

# %%
# %pip install lifelines
# %pip install xgbse --no-deps
# %pip install "lifelines>=0.29.0,<0.30.0"
# %pip install shap

# %%
# !pip install xgboost
# !pip install scikit-survival
# Out:
# Requirement already satisfied: xgboost in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (3.2.0)
# Requirement already satisfied: numpy in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from xgboost) (2.4.4)
# Requirement already satisfied: scipy in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from xgboost) (1.16.3)
# Collecting scikit-survival
#   Downloading scikit_survival-0.27.0-cp312-cp312-win_amd64.whl.metadata (7.1 kB)
# Collecting ecos (from scikit-survival)
#   Downloading ecos-2.0.14-cp312-cp312-win_amd64.whl.metadata (8.2 kB)
# Requirement already satisfied: joblib in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from scikit-survival) (1.5.2)
# Requirement already satisfied: numexpr in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from scikit-survival) (2.14.1)
# Requirement already satisfied: numpy>=2.0.0 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from scikit-survival) (2.4.4)
# Collecting osqp>=1.0.2 (from scikit-survival)
#   Downloading osqp-1.1.1-cp312-cp312-win_amd64.whl.metadata (2.2 kB)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from scikit-survival) (2.3.3)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from scikit-survival) (1.16.3)
# Collecting scikit-learn<1.9,>=1.8.0 (from scikit-survival)
#   Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from scikit-learn<1.9,>=1.8.0->scikit-survival) (3.5.0)
# Requirement already satisfied: jinja2 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from osqp>=1.0.2->scikit-survival) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from osqp>=1.0.2->scikit-survival) (80.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from pandas>=2.2.0->scikit-survival) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from pandas>=2.2.0->scikit-survival) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from pandas>=2.2.0->scikit-survival) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->scikit-survival) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jcari\anaconda3\envs\fall2526\lib\site-packages (from jinja2->osqp>=1.0.2->scikit-survival) (3.0.2)
# Downloading scikit_survival-0.27.0-cp312-cp312-win_amd64.whl (808 kB)
#    ---------------------------------------- 0.0/808.3 kB ? eta -:--:--
#    ---------------------------------------- 808.3/808.3 kB 8.7 MB/s  0:00:00
# Downloading scikit_learn-1.8.0-cp312-cp312-win_amd64.whl (8.0 MB)
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ------------- -------------------------- 2.6/8.0 MB 13.7 MB/s eta 0:00:01
#    --------------------------- ------------ 5.5/8.0 MB 14.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.0/8.0 MB 13.8 MB/s  0:00:00
# Downloading osqp-1.1.1-cp312-cp312-win_amd64.whl (310 kB)
# Downloading ecos-2.0.14-cp312-cp312-win_amd64.whl (72 kB)
# Installing collected packages: scikit-learn, osqp, ecos, scikit-survival
#
#   Attempting uninstall: scikit-learn
#
#     Found existing installation: scikit-learn 1.7.2
#
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#     Uninstalling scikit-learn-1.7.2:
#    ---------------------------------------- 0/4 [scikit-learn]
#       Successfully uninstalled scikit-learn-1.7.2
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [osqp]
#    ------------------------------ --------- 3/4 [scikit-survival]
#    ------------------------------ --------- 3/4 [scikit-survival]
#    ------------------------------ --------- 3/4 [scikit-survival]
#    ---------------------------------------- 4/4 [scikit-survival]
#
# Successfully installed ecos-2.0.14 osqp-1.1.1 scikit-learn-1.8.0 scikit-survival-0.27.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xgbse 0.3.3 requires numpy<2.0.0,>=1.26.4, but you have numpy 2.4.4 which is incompatible.
# xgbse 0.3.3 requires xgboost<3.0.0,>=2.1.0, but you have xgboost 3.2.0 which is incompatible.

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns
import random, sys, shap
from itertools import product as iproduct
from xgboost import XGBClassifier
from xgbse import XGBSEKaplanNeighbors
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE, RFECV, mutual_info_classif
from sklearn.metrics import (classification_report, roc_auc_score, confusion_matrix,
                             average_precision_score, precision_recall_curve, make_scorer)
from sklearn.model_selection import (train_test_split, PredefinedSplit, RandomizedSearchCV)
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.inspection import permutation_importance
from scipy.stats import randint, uniform, loguniform
from scipy.ndimage import uniform_filter1d
from lifelines import KaplanMeierFitter
from sksurv.ensemble import RandomSurvivalForest
from sksurv.util import Surv
from sksurv.metrics import concordance_index_censored
import time

# %%
#!conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#!conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/msys2

# %%
# Style settings for presentation charts
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = [10, 6]

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# ## 1.2 Data Loading
#
# </a>

# %%
#Import
#BNP = pd.read_csv('Preprocessed_dataset_BNP2.csv')
df = pd.read_csv('Preprocessed_dataset_BNP2.csv')

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# ## 2. Target Engineering
#
# </a>

# %% [markdown]
# Before we begin, we will create a Target feature for our survival models.

# %%
# 1. Classification Target (Binary)
df['TARGET'] = df['CHURN'].fillna(0).astype(int)

# 2. Survival Targets (Event and Duration)
df['event'] = df['TARGET']
# Ensure duration is at least 1 day so Cox doesn't crash
df['duration'] = df['DOSSIER_DURATION_DAYS'].clip(lower=1).fillna(1)
df['CLOSE_DATE'] = pd.to_datetime(df['CLOSE_DATE'])

# %% [markdown]
# We will also select the apropriate features from our dataset, so that we can avoid possible data leakage.

# %%
features_for_survival = [
    'DURDEG', 'MENSALIDADE', 'CRD_min', 'MTFINO', 'SREC',
    'RESSO_mean', 'NBENF_mean', 'delay_sum',
    'N_PREVIOUS_DOSSIERS', 'previous_churn_rate',
    'count_cl_mean', 'subcount_total_mean', 'montvenc_cl_mean', 'montenc_total_mean',
    'montabatv_cl_mean', 'montabatv_total_mean', 'dividas_cl_mean', 
    'dividas_total_mean', 'ks_score_tier', 'HIGH_RISK_CURRENT', 'is_risky',
    'sdem_age', 'active_credit_ratio', 'POLE', 'PRODALP', 'PAGAMENTO', 
    'MODCONTACTO', 'sdem_SITFAM', 'sdem_HABITAT', 'kp_sqe', 'NATIO',
    'AGFIN', 'PTT'
]

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# ## 3. Split
#
# </a>

# %% [markdown]
# In this chapter, we will begin by separating our data in a train_df, containing only closed dossiers, and a test_df, containing only open dossiers. This step is important since we can only train a model on a dataset with a known target. In this notebook, since our goal is, not only to predict who is going to churn but also how long until it happens, we need to train our model on a dataset of closed dossiers, where we can identify the ones who churned and the time it took for them.

# %%
train_df = df[df['CLOSE_DATE'].notna()].copy()
test_df = df[df['CLOSE_DATE'].isna()].copy()

# %% [markdown]
# We will now separate our train_df in a train_data and a val_data.
#
# Instead of implementing a regular train_test_split, we decided on an aproach that separates our data in a way that we train on an older dataset and validate on the most recent closed dossiers. We believe this implementation to be better since our final model will be predicting on future data.

# %%
# Temporal split: train on oldest contracts, validate on most recent
train_df_sorted = train_df.sort_values('CLOSE_DATE')

# 80% oldest -> train | 20% most recent -> validation
cutoff = train_df_sorted['CLOSE_DATE'].quantile(0.8)
train_data = train_df_sorted[train_df_sorted['CLOSE_DATE'] <= cutoff].copy()
val_data   = train_df_sorted[train_df_sorted['CLOSE_DATE'] >  cutoff].copy()

print(f"Cutoff date: {cutoff.date()}")
print(f"Train size: {len(train_data):,} ({len(train_data)/len(train_df):.1%})")
print(f"Val size:   {len(val_data):,} ({len(val_data)/len(train_df):.1%})")
print(f"\nChurn rate train: {train_data['TARGET'].mean():.3f}")
print(f"Churn rate val:   {val_data['TARGET'].mean():.3f}")
# Out:
# Cutoff date: 2025-06-30
# Train size: 63,118 (82.4%)
# Val size:   13,528 (17.6%)
#
# Churn rate train: 0.860
# Churn rate val:   0.774

# %% [markdown]
# Finally, we will separate our data even further by creating X_train and X_val (containing every previously selected feature from train_data and val_data, respective) and y_train and y_val (containing the target features from train_data and val_data, respective).
#
# We also created X_test, which consists of the selected features from our test_data.

# %%
# Create X by selecting columns from our feature list
X_train = train_data[features_for_survival].copy()
X_val = val_data[features_for_survival].copy()
X_test = test_df[features_for_survival].copy()

# Create y targets
y_train = train_data['TARGET']
y_val = val_data['TARGET']

print("Shape X_train:", X_train.shape)
print("Shape X_val:", X_val.shape)
# Out:
# Shape X_train: (63118, 33)
# Shape X_val: (13528, 33)

# %% [markdown]
# ## Encoding

# %% [markdown]
# In this chapter, we will encode our categorical features.
#
# We chose to use frequency encoder, based on the dimensionality of our categorical variables.

# %%
# Convert AGFIN and PTT to string (categorical but stored as numbers)
for col in ['AGFIN', 'PTT']:
    X_train[col] = X_train[col].astype(str)
    X_val[col]   = X_val[col].astype(str)
    X_test[col]  = X_test[col].astype(str)

# Identify text columns within our filtered X_train
cat_cols = X_train.select_dtypes(include=['object']).columns

for col in cat_cols:
    # 2. Calculate frequency in Train
    freq_map = X_train[col].value_counts(normalize=True)

    # 3. Create the new variable with _encoded suffix
    X_train[f"{col}_encoded"] = X_train[col].map(freq_map)
    X_val[f"{col}_encoded"]   = X_val[col].map(freq_map).fillna(0)
    X_test[f"{col}_encoded"]  = X_test[col].map(freq_map).fillna(0)

    # 4. Drop original column to avoid confusing the model
    X_train = X_train.drop(columns=[col])
    X_val   = X_val.drop(columns=[col])
    X_test  = X_test.drop(columns=[col])

print(f"Encoding complete. Created '_encoded' versions for: {list(cat_cols)}")
print(f"Columns in X_train: {X_train.columns.tolist()}")
# Out:
# Encoding complete. Created '_encoded' versions for: ['POLE', 'PRODALP', 'PAGAMENTO', 'MODCONTACTO', 'sdem_SITFAM', 'sdem_HABITAT', 'kp_sqe', 'NATIO', 'AGFIN', 'PTT']
# Columns in X_train: ['DURDEG', 'MENSALIDADE', 'CRD_min', 'MTFINO', 'SREC', 'RESSO_mean', 'NBENF_mean', 'delay_sum', 'N_PREVIOUS_DOSSIERS', 'previous_churn_rate', 'count_cl_mean', 'subcount_total_mean', 'montvenc_cl_mean', 'montenc_total_mean', 'montabatv_cl_mean', 'montabatv_total_mean', 'dividas_cl_mean', 'dividas_total_mean', 'ks_score_tier', 'HIGH_RISK_CURRENT', 'is_risky', 'sdem_age', 'active_credit_ratio', 'POLE_encoded', 'PRODALP_encoded', 'PAGAMENTO_encoded', 'MODCONTACTO_encoded', 'sdem_SITFAM_encoded', 'sdem_HABITAT_encoded', 'kp_sqe_encoded', 'NATIO_encoded', 'AGFIN_encoded', 'PTT_encoded']

# %%
X_train.head()
# Out:
#        DURDEG  MENSALIDADE  CRD_min   MTFINO  SREC  RESSO_mean  NBENF_mean  \
# 92794      60    93.730818      0.0   5000.0   0.0     993.649         0.0
# 84813      76   161.798899      0.0   8000.0   0.0    1867.787         0.0
# 84810      24   272.163616      0.0   5000.0   0.0    1079.225         1.0
# 84806      84   109.792569      0.0   5000.0   0.0    1170.522         2.0
# 84804      84   996.257424      0.0  45000.0   0.0    3061.034         0.0
#
#        delay_sum  N_PREVIOUS_DOSSIERS  previous_churn_rate  ...  POLE_encoded  \
# 92794          0                    0                 -1.0  ...      0.984854
# 84813          0                    0                 -1.0  ...      0.984854
# 84810          0                    0                 -1.0  ...      0.984854
# 84806          0                    0                 -1.0  ...      0.984854
# 84804          0                    0                 -1.0  ...      0.984854
#
#        PRODALP_encoded  PAGAMENTO_encoded  MODCONTACTO_encoded  \
# 92794         0.750166           0.963576             0.017776
# 84813         0.750166           0.963576             0.599037
# 84810         0.750166           0.963576             0.378577
# 84806         0.750166           0.963576             0.599037
# 84804         0.088105           0.963576             0.378577
#
#        sdem_SITFAM_encoded  sdem_HABITAT_encoded  kp_sqe_encoded  \
# 92794             0.199230              0.358741        0.716689
# 84813             0.191483              0.358741        0.716689
# 84810             0.199230              0.266374        0.020200
# 84806             0.406081              0.358741        0.716689
# 84804             0.406081              0.266374        0.716689
#
#        NATIO_encoded  AGFIN_encoded  PTT_encoded
# 92794       0.990827       0.271634     0.001109
# 84813       0.990827       0.489116     0.003961
# 84810       0.990827       0.271634     0.001410
# 84806       0.990827       0.271634     0.000555
# 84804       0.990827       0.271634     0.003010
#
# [5 rows x 33 columns]

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# # 4. Feature Selection
#
# </a>

# %% [markdown]
# In this chapter, we will train diferent feature selection models to better understand what features to keep for our final model.
#
# We decided on:
# - Filter Methods:
#     - Variance Check;
#     - Correlation Check;
#     - Mutual Information;
# - Wrapper Methods:
#     - RFE;
#     - RFECV;
# - Embedded Methods:
#     - Random Forest;
#     - XGBoost;
#     - Random Survival Forest.
#
# In the end of this chapter, we will make a final insight on our feature selection results and determine which features to run in our final models.

# %% [markdown]
# ## 4.1 Filter Methods

# %% [markdown]
# Filter Methods are Feature Selection techniques that use statistical measures to evaluate the relevance of each variable with respect with to the target, without relying on a learning model.

# %% [markdown]
# ## 4.1.1 Variance

# %% [markdown]
# In this filter-based method, we will see if any of our variables is constant in the dataset.

# %%
variances = X_train.var()

# Identify columns with almost no variation (threshold 0.01)
low_variance_cols = variances[variances < 0.01].index

print(low_variance_cols)
# Out:
# Index(['CRD_min', 'sdem_HABITAT_encoded', 'NATIO_encoded', 'PTT_encoded'], dtype='object')

# %% [markdown]
# According with the output of the cell above, we can see that 'CRD_min', 'sdem_HABITAT_encoded', 'NATIO_encoded' and 'PTT_encoded' have a very low variance (lower than 0.01). This is something we will have in mind during our final insights.

# %% [markdown]
# ## 4.1.2 Correlation Matrix

# %% [markdown]
# In this filter-based method, we will see if any of our variables highly correlated in the dataset.

# %%
# 1. Calculate the correlation matrix
corr_matrix = X_train.corr()

# 2. Heatmap visualization
plt.figure(figsize=(15, 12))
# Divergent colormap (coolwarm) to distinguish positive and negative correlations
sns.heatmap(corr_matrix,
            annot=False, # False because with many columns the numbers are unreadable
            cmap='coolwarm',
            vmin=-1, vmax=1, # Fixed scale from -1 to 1
            linewidths=0.1)

plt.title("Correlation Matrix — Identifying Redundancies", fontsize=15)
plt.show()

# %% [markdown]
# **Correlation Matrix Analysis:** The heatmap shows the correlations between all variables. The darker the color (blue or red), the stronger the relationship between two variables.
#
# Pairs with correlation above 0.90 are problematic because they carry redundant information — keeping both can confuse the models. The most correlated pairs found are:
# - MENSALIDADE-MTFINO (0.88);
# - N_PREVIOUS_DOSSIERS-previous_churn_rate (0.82).
#
# In the final insights, the consensus method will decide which to keep from each pair.

# %%
# Use only the upper triangle of the matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    
# Find pairs with high correlation
high_corr_pairs = (upper.stack().reset_index())
high_corr_pairs.columns = ['feature_1', 'feature_2', 'correlation']
high_corr_pairs = high_corr_pairs[high_corr_pairs['correlation'].abs() > 0.50]
print(high_corr_pairs)
# Out:
#                feature_1             feature_2  correlation
# 1                 DURDEG                MTFINO     0.576911
# 31           MENSALIDADE                MTFINO     0.881034
# 196  N_PREVIOUS_DOSSIERS   previous_churn_rate     0.817178
# 243        count_cl_mean   subcount_total_mean     0.614037
# 248        count_cl_mean       dividas_cl_mean     0.575280
# 286     montvenc_cl_mean    montenc_total_mean     0.781517
# 325    montabatv_cl_mean  montabatv_total_mean     0.611065
# 426             is_risky        kp_sqe_encoded     0.602231

# %% [markdown]
# ## 4.1.3 Mutual Information

# %% [markdown]
# Mutual Information shows how much information each variable gives us about whether the client will churn. Unlike correlation, this method captures non-linear relationships (e.g., a variable that only matters above a certain value).

# %%
mi_scores = mutual_info_classif(X_train, y_train, random_state=42)

# 2. Organize results in a Pandas Series
mi_importance = pd.Series(mi_scores, index=X_train.columns).sort_values(ascending=False)

plt.figure(figsize=(10, 8))
mi_importance.sort_values(ascending=True).plot(kind='barh', color='teal')
plt.title("Top Variables — Mutual Information Score")
plt.xlabel("Information Gain / Dependency Score")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# The most predictive variables are RESSO_mean, dividas_cl_mean, dividas_total_mean, active_credit_ratio and count_cl_mean. Variables at the bottom of the chart (close to zero) barely help predict churn.

# %% [markdown]
# ## 4.2 Wrapper Methods

# %% [markdown]
# Wrapper Methods are Feature Selection techniques that evaluate subsets of features by training and testing a predictive model. They use the model’s performance as a criterion to select the most relevant features, thus considering interactions between variables but at a higher computational cost.

# %% [markdown]
# ## 4.2.1 RFE

# %%
rf = RandomForestClassifier(n_estimators=50, max_depth=5, random_state=42, n_jobs=-1)

selector = RFE(estimator=rf, n_features_to_select=15, step=1, verbose=1)

# %%
selector.fit(X_train, y_train)

selected_features = X_train.columns[selector.get_support()].tolist()
ranking = pd.DataFrame({'Feature': X_train.columns, 'Ranking': selector.ranking_}).sort_values('Ranking')

print(f"\nThe model selected these 15 variables: \n{selected_features}")
# Out:
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
#
# The model selected these 15 variables:
# ['DURDEG', 'MTFINO', 'SREC', 'RESSO_mean', 'delay_sum', 'N_PREVIOUS_DOSSIERS', 'previous_churn_rate', 'count_cl_mean', 'subcount_total_mean', 'montenc_total_mean', 'dividas_cl_mean', 'dividas_total_mean', 'active_credit_ratio', 'PRODALP_encoded', 'kp_sqe_encoded']

# %% [markdown]
# According to RFE, our best combination with 15 features is 'DURDEG', 'MTFINO', 'SREC', 'RESSO_mean', 'delay_sum', 'N_PREVIOUS_DOSSIERS', 'previous_churn_rate', 'count_cl_mean', 'subcount_total_mean', 'montenc_total_mean', 'dividas_cl_mean', 'dividas_total_mean', 'active_credit_ratio', 'PRODALP_encoded' and 'kp_sqe_encoded'.
#
# We will have this in mind during our final insights.

# %% [markdown]
# ## 4.2.2 RFECV

# %%
# RFECV with our predefined temporal split (does not use random k-fold)
split_indices = [-1] * len(X_train) + [0] * len(X_val)
ps = PredefinedSplit(split_indices)

X_rfecv = pd.concat([X_train, X_val], ignore_index=True)
y_rfecv = pd.concat([y_train, y_val], ignore_index=True)

rfecv = RFECV(
    estimator=RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42, n_jobs=-1),
    cv=ps,
    scoring='roc_auc',
    min_features_to_select=5,
    step=1,
    verbose=1
)

rfecv.fit(X_rfecv, y_rfecv)

print(f"\nOptimal number of features: {rfecv.n_features_}")
rfecv_features = X_train.columns[rfecv.support_].tolist()
print(f"\nFeatures selected by RFECV:\n{rfecv_features}")
# Out:
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
# Fitting estimator with 31 features.
# Fitting estimator with 30 features.
# Fitting estimator with 29 features.
# Fitting estimator with 28 features.
# Fitting estimator with 27 features.
# Fitting estimator with 26 features.
# Fitting estimator with 25 features.
# Fitting estimator with 24 features.
# Fitting estimator with 23 features.
# Fitting estimator with 22 features.
# Fitting estimator with 21 features.
# Fitting estimator with 20 features.
# Fitting estimator with 19 features.
# Fitting estimator with 18 features.
# Fitting estimator with 17 features.
# Fitting estimator with 16 features.
# Fitting estimator with 15 features.
# Fitting estimator with 14 features.
# Fitting estimator with 13 features.
# Fitting estimator with 12 features.
# Fitting estimator with 11 features.
# Fitting estimator with 10 features.
# Fitting estimator with 9 features.
# Fitting estimator with 8 features.
# Fitting estimator with 7 features.
# Fitting estimator with 6 features.
# Fitting estimator with 33 features.
# Fitting estimator with 32 features.
#
# Optimal number of features: 31
#
# Features selected by RFECV:
# ['DURDEG', 'MENSALIDADE', 'MTFINO', 'SREC', 'RESSO_mean', 'NBENF_mean', 'delay_sum', 'N_PREVIOUS_DOSSIERS', 'previous_churn_rate', 'count_cl_mean', 'subcount_total_mean', 'montvenc_cl_mean', 'montenc_total_mean', 'montabatv_total_mean', 'dividas_cl_mean', 'dividas_total_mean', 'ks_score_tier', 'HIGH_RISK_CURRENT', 'is_risky', 'sdem_age', 'active_credit_ratio', 'POLE_encoded', 'PRODALP_encoded', 'PAGAMENTO_encoded', 'MODCONTACTO_encoded', 'sdem_SITFAM_encoded', 'sdem_HABITAT_encoded', 'kp_sqe_encoded', 'NATIO_encoded', 'AGFIN_encoded', 'PTT_encoded']

# %%
# Performance curve vs number of features
plt.figure(figsize=(10, 5))
plt.plot(range(rfecv.min_features_to_select, len(rfecv.cv_results_['mean_test_score']) + rfecv.min_features_to_select),
         rfecv.cv_results_['mean_test_score'], marker='o', color='teal')
plt.axvline(x=rfecv.n_features_, color='red', linestyle='--', label=f'Optimal: {rfecv.n_features_} features')
plt.xlabel("Number of Features")
plt.ylabel("ROC-AUC (Validation)")
plt.title("RFECV — Optimal Number of Features")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
# Detect the elbow automatically
# Criterion: first point where marginal gain falls below 5% of total gain
scores = rfecv.cv_results_['mean_test_score']
gains  = np.diff(scores)
total_gain = scores[-1] - scores[0]

elbow_candidates = np.where(gains < 0.05 * total_gain)[0]
n_elbow = 15

print(f"Elbow detected at: {n_elbow} features")
print(f"ROC-AUC with {n_elbow} features: {scores[n_elbow - rfecv.min_features_to_select]:.4f}")
print(f"ROC-AUC with {rfecv.n_features_} features: {scores[-1]:.4f}")
print(f"Additional gain from {rfecv.n_features_ - n_elbow} extra features: {scores[-1] - scores[n_elbow - rfecv.min_features_to_select]:.4f}")
# Out:
# Elbow detected at: 15 features
# ROC-AUC with 15 features: 0.7309
# ROC-AUC with 31 features: 0.7449
# Additional gain from 16 extra features: 0.0140

# %% [markdown]
# **RFECV Curve Analysis:** This chart shows how model performance (ROC-AUC) changes as we add more variables. The curve rises quickly up to ~15 features and then stabilizes — meaning the 16 additional features barely improve the model (only 0.0140 AUC gain). We identified the "elbow" at 15 features, which is the best balance between simplicity and performance.
#
# We use this number as a reference during the final insights.

# %%
# RFE with n=elbow to identify the specific features
rfe_elbow = RFE(
    estimator=RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42, n_jobs=-1),
    n_features_to_select=n_elbow,
    step=1,
    verbose=0
)
rfe_elbow.fit(X_train, y_train)

elbow_features = X_train.columns[rfe_elbow.support_].tolist()
print(f"Top {n_elbow} features (RFECV elbow):")
for f in elbow_features:
    print(f"  - {f}")
# Out:
# Top 15 features (RFECV elbow):
#   - DURDEG
#   - MENSALIDADE
#   - MTFINO
#   - RESSO_mean
#   - delay_sum
#   - previous_churn_rate
#   - count_cl_mean
#   - subcount_total_mean
#   - montenc_total_mean
#   - dividas_cl_mean
#   - dividas_total_mean
#   - sdem_age
#   - active_credit_ratio
#   - kp_sqe_encoded
#   - PTT_encoded

# %% [markdown]
# ## 4.3 Embedded methods

# %% [markdown]
# Embedded Methods are Feature Selection techniques that perform feature selection during the model training process itself. They integrate the selection of features with the model’s learning algorithm, achieving a balance between the efficiency of filter methods and the accuracy of wrapper methods.

# %% [markdown]
# ## 4.3.1 Random Forest

# %%
rf_model = RandomForestClassifier(
    n_estimators=300,
    random_state=42,
    class_weight='balanced',
    n_jobs=-1
)

# Train the model
rf_model.fit(X_train, y_train)

# Make Validation Predictions
y_val_pred = rf_model.predict(X_val)
y_val_prob = rf_model.predict_proba(X_val)[:, 1]

# Show Metrics
print("\nClassification Report (Validation Set):")
print(classification_report(y_val, y_val_pred))
print(f"ROC-AUC Score: {roc_auc_score(y_val, y_val_prob):.4f}")

# Extract and Visualize Feature Importance
rf_importance = pd.Series(rf_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
rf_importance.head(15).sort_values(ascending=True).plot(kind='barh', color='skyblue')
plt.title("Top 15 Variables — Random Forest Importance")
plt.xlabel("Gini Importance")
plt.show()

# Save the top 15 list for the final consensus
rf_selected_features = rf_importance.head(15).index.tolist()
# Out:
# Classification Report (Validation Set):
#               precision    recall  f1-score   support
#
#            0       0.64      0.25      0.36      3063
#            1       0.81      0.96      0.88     10465
#
#     accuracy                           0.80     13528
#    macro avg       0.73      0.61      0.62     13528
# weighted avg       0.78      0.80      0.76     13528
#
# ROC-AUC Score: 0.7484

# %% [markdown]
# **Random Forest Feature Importance Analysis:** The Random Forest assigned importance to each variable based on how often each one was used to split the data in the decision trees (Gini Importance). active_credit_ratio, dividas_cl_mean and delay_sum stand out. The model achieved ROC-AUC of 0.7484 on the validation set. This model uses all 28 features — the final selection will reduce this number through the consensus table.

# %% [markdown]
# ## 4.3.2 XGBOOST

# %%
# Calculate the weights
neg = (y_train == 0).sum()
pos = (y_train == 1).sum()
scale_pos_weight = neg / pos

print("Negative class count:", neg)
print("Positive class count:", pos)
print("scale_pos_weight:", scale_pos_weight)

# Configure the Model
xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=4,                # Shallower trees to avoid overfitting
    learning_rate=0.05,         # Slower step for greater precision
    subsample=0.8,              # Uses 80% of data in each tree
    colsample_bytree=0.8,       # Uses 80% of columns in each tree
    scale_pos_weight=scale_pos_weight,
    random_state=42,
    n_jobs=-1,
    eval_metric='logloss'
)

# Train the model
print(f"Training XGBoost with scale_pos_weight: {scale_pos_weight:.2f}...")
xgb_model.fit(X_train, y_train)

# Predictions and Evaluation
y_val_pred_xgb = xgb_model.predict(X_val)
y_val_prob_xgb = xgb_model.predict_proba(X_val)[:, 1]

print(classification_report(y_val, y_val_pred_xgb))
print(f" Validation ROC-AUC:: {roc_auc_score(y_val, y_val_prob_xgb):.4f}")


# Visualize Top 15 Variables
xgb_importance = pd.Series(xgb_model.feature_importances_, index=X_train.columns).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
xgb_importance.head(15).sort_values(ascending=True).plot(kind='barh', color='salmon')
plt.title("Top 15 Variables — XGBoost Importance")
plt.xlabel("F-Score / Gain Importance")
plt.show()

xgb_selected_features = xgb_importance.head(15).index.tolist()
# Out:
# Negative class count: 8808
# Positive class count: 54310
# scale_pos_weight: 0.16218007733382434
# Training XGBoost with scale_pos_weight: 0.16...
#               precision    recall  f1-score   support
#
#            0       0.33      0.80      0.47      3063
#            1       0.90      0.53      0.67     10465
#
#     accuracy                           0.59     13528
#    macro avg       0.62      0.67      0.57     13528
# weighted avg       0.77      0.59      0.63     13528
#
#  Validation ROC-AUC:: 0.7529

# %% [markdown]
# **XGBoost Feature Importance Analysis:** XGBoost uses gradient boosting (trees that learn from the errors of the previous ones). The scale_pos_weight=0.16 corrects the class imbalance — there are far more contracts with churn (54,310) than without (8,808). The most important variables for XGBoost differ from the Random Forest, which is expected — each algorithm "looks" at the data differently. This is why we used multiple methods and then voted on a consensus.

# %% [markdown]
# ## 4.3.3 Random Survival Forest

# %%
X_train_rsf = X_train.copy().astype(np.float32)
X_val_rsf = X_val.copy().astype(np.float32)

y_train_rsf = Surv.from_dataframe(
    event='event',
    time='duration',
    data=train_data
)

y_val_rsf = Surv.from_dataframe(
    event='event',
    time='duration',
    data=val_data
)


# Random Survival Forest model

rsf = RandomSurvivalForest(
    n_estimators=100,          # fewer trees to save memory
    min_samples_split=20,
    min_samples_leaf=30,
    max_features="sqrt",
    n_jobs=2,               
    random_state=42,
    low_memory=True           
)

rsf.fit(X_train_rsf, y_train_rsf)

# Performance

train_cindex = rsf.score(X_train_rsf, y_train_rsf)
val_cindex = rsf.score(X_val_rsf, y_val_rsf)

print("Train C-index:", train_cindex)
print("Validation C-index:", val_cindex)

# Permutation importance

perm_result = permutation_importance(
    rsf,
    X_val_rsf,
    y_val_rsf,
    n_repeats=3,          # fewer repeats to save memory/time
    random_state=42,
    n_jobs=1              # important to avoid blowing up RAM
)

rsf_importance = pd.Series(
    perm_result.importances_mean,
    index=X_val_rsf.columns
).sort_values(ascending=False)

print("\nTop 25 RSF full feature importances:")
print(rsf_importance)

rsf_importance_df = pd.DataFrame({
    "importance_mean": perm_result.importances_mean,
    "importance_std": perm_result.importances_std
}, index=X_val_rsf.columns).sort_values("importance_mean", ascending=False)

print("\nTop 25 RSF full feature importances with std:")
print(rsf_importance_df)
# Out:
# Train C-index: 0.7708042491535575
# Validation C-index: 0.685670153210344
#
# Top 25 RSF full feature importances:
# DURDEG                  9.897902e-02
# MTFINO                  2.061157e-02
# previous_churn_rate     1.542093e-02
# sdem_age                1.103518e-02
# delay_sum               9.329712e-03
# dividas_total_mean      7.378755e-03
# N_PREVIOUS_DOSSIERS     6.629475e-03
# active_credit_ratio     4.287064e-03
# MENSALIDADE             4.220572e-03
# dividas_cl_mean         2.900253e-03
# RESSO_mean              2.649877e-03
# sdem_SITFAM_encoded     2.445282e-03
# PRODALP_encoded         1.853530e-03
# AGFIN_encoded           1.381229e-03
# count_cl_mean           1.366325e-03
# kp_sqe_encoded          1.224524e-03
# is_risky                1.020441e-03
# MODCONTACTO_encoded     6.474620e-04
# montenc_total_mean      3.233006e-04
# SREC                    3.023972e-04
# NBENF_mean              2.310691e-04
# HIGH_RISK_CURRENT       1.451029e-04
# montvenc_cl_mean        3.419034e-05
# PAGAMENTO_encoded       1.089250e-05
# NATIO_encoded           2.717908e-06
# CRD_min                 0.000000e+00
# montabatv_cl_mean       0.000000e+00
# montabatv_total_mean   -3.234363e-07
# POLE_encoded           -1.422076e-05
# PTT_encoded            -1.488328e-05
# subcount_total_mean    -2.963146e-04
# ks_score_tier          -3.443605e-04
# sdem_HABITAT_encoded   -5.111284e-04
# dtype: float64
#
# Top 25 RSF full feature importances with std:
#                       importance_mean  importance_std
# DURDEG                   9.897902e-02    1.897552e-03
# MTFINO                   2.061157e-02    4.896622e-04
# previous_churn_rate      1.542093e-02    3.142549e-04
# sdem_age                 1.103518e-02    6.164811e-04
# delay_sum                9.329712e-03    3.560314e-04
# dividas_total_mean       7.378755e-03    7.542846e-05
# N_PREVIOUS_DOSSIERS      6.629475e-03    4.653288e-04
# active_credit_ratio      4.287064e-03    2.796026e-04
# MENSALIDADE              4.220572e-03    2.490266e-04
# dividas_cl_mean          2.900253e-03    2.160072e-04
# RESSO_mean               2.649877e-03    5.792201e-04
# sdem_SITFAM_encoded      2.445282e-03    3.290878e-04
# PRODALP_encoded          1.853530e-03    1.147028e-04
# AGFIN_encoded            1.381229e-03    4.745423e-04
# count_cl_mean            1.366325e-03    9.919393e-05
# kp_sqe_encoded           1.224524e-03    9.995723e-05
# is_risky                 1.020441e-03    1.394121e-04
# MODCONTACTO_encoded      6.474620e-04    3.934816e-04
# montenc_total_mean       3.233006e-04    8.740691e-05
# SREC                     3.023972e-04    4.539071e-05
# NBENF_mean               2.310691e-04    9.437267e-05
# HIGH_RISK_CURRENT        1.451029e-04    6.963431e-05
# montvenc_cl_mean         3.419034e-05    3.776458e-05
# PAGAMENTO_encoded        1.089250e-05    3.485616e-05
# NATIO_encoded            2.717908e-06    3.256166e-07
# CRD_min                  0.000000e+00    0.000000e+00
# montabatv_cl_mean        0.000000e+00    0.000000e+00
# montabatv_total_mean    -3.234363e-07    6.585882e-07
# POLE_encoded            -1.422076e-05    8.097849e-06
# PTT_encoded             -1.488328e-05    9.066360e-05
# subcount_total_mean     -2.963146e-04    1.624967e-04
# ks_score_tier           -3.443605e-04    6.926800e-05
# sdem_HABITAT_encoded    -5.111284e-04    2.686011e-04

# %%
mask = rsf_importance != 0
data = rsf_importance[mask].sort_values()

colors = ['blue' if v > 0 else 'red' for v in data]

# find position where positives begin
split_index = (data > 0).idxmax()  # first positive feature
split_position = list(data.index).index(split_index)

plt.figure(figsize=(8,6))
data.plot(kind='barh', color=colors)

# horizontal line to clearly separate negative values
plt.axhline(split_position - 0.5, color='red', linewidth=2)

plt.title("Random Survival Forest Feature Importance")
plt.xlabel("Importance")
plt.ylabel("Feature")

plt.show()

# %% [markdown]
# **RSF Feature Importance Analysis:** The Random Survival Forest (RSF) predicts when churn will happen (not just if). Importance is measured by permutation importance — each variable is shuffled and we see how much the model worsens. DURDEG dominates by far, followed by MTFINO and previous_churn_rate. Train C-index: ~0.77 vs Validation C-index: ~0.686 — gap of ~0.084, within acceptable range for survival trees with datasets of this size.

# %% [markdown]
# ## 4.4 Final Insights

# %% [markdown]
# In this chapter, we will analyse every result from the diferent feature selection methods and determine which features to keep for our final models.

# %%
# Filters (elimination)
variance_ok = set(variances[variances >= 0.01].index)
dropped_var = set(X_train.columns) - variance_ok

# For pairs with |corr| > 0.90, drop the weaker of the pair (tiebreak by MI)
corr_drop = set()
for _, row in high_corr_pairs[high_corr_pairs['correlation'].abs() > 0.90].iterrows():
    f1, f2 = row['feature_1'], row['feature_2']
    if mi_importance.get(f1, 0) >= mi_importance.get(f2, 0):
        corr_drop.add(f2)
    else:
        corr_drop.add(f1)

survived = variance_ok - corr_drop
print(f"Filters: {len(X_train.columns)} features -> {len(survived)} survive")
if dropped_var:
    print(f"  Dropped by low variance: {sorted(dropped_var)}")
if corr_drop:
    print(f"  Dropped by correlation (|r|>0.90): {sorted(corr_drop)}")

# Voting (6 methods, top N = n_elbow)
top_n = n_elbow

mi_set    = set(mi_importance.head(top_n).index) & survived
rfe_set   = set(selected_features) & survived        # RFE n=15
rfecv_set = set(elbow_features) & survived            # RFECV elbow
rf_set    = set(rf_importance.head(top_n).index) & survived
xgb_set   = set(xgb_importance.head(top_n).index) & survived
rsf_set   = set(rsf_importance.head(top_n).index) & survived

all_survived = sorted(survived)

consensus_df = pd.DataFrame({
    'Feature' : all_survived,
    'MI'      : [1 if f in mi_set    else 0 for f in all_survived],
    'RFE'     : [1 if f in rfe_set   else 0 for f in all_survived],
    'RFECV'   : [1 if f in rfecv_set else 0 for f in all_survived],
    'RF_Imp'  : [1 if f in rf_set    else 0 for f in all_survived],
    'XGB_Imp' : [1 if f in xgb_set   else 0 for f in all_survived],
    'RSF_Imp' : [1 if f in rsf_set   else 0 for f in all_survived],
})
consensus_df['Score'] = consensus_df[['MI','RFE','RFECV','RF_Imp','XGB_Imp','RSF_Imp']].sum(axis=1)
consensus_df = consensus_df.sort_values('Score', ascending=False).reset_index(drop=True)

print("\n=== COMPLETE CONSENSUS TABLE ===")
print(consensus_df.to_string(index=False))

# Final selection
best_features = consensus_df[consensus_df['Score'] >= 3]['Feature'].tolist()
print(f"\n-> Final features (>=3/6 votes): {len(best_features)}")
print(best_features)
# Out:
# Filters: 33 features -> 29 survive
#   Dropped by low variance: ['CRD_min', 'NATIO_encoded', 'PTT_encoded', 'sdem_HABITAT_encoded']
#
# === COMPLETE CONSENSUS TABLE ===
#              Feature  MI  RFE  RFECV  RF_Imp  XGB_Imp  RSF_Imp  Score
#  previous_churn_rate   1    1      1       1        1        1      6
#   dividas_total_mean   1    1      1       1        1        1      6
#      dividas_cl_mean   1    1      1       1        1        1      6
#            delay_sum   1    1      1       1        1        1      6
#  active_credit_ratio   1    1      1       1        1        1      6
#        count_cl_mean   1    1      1       1        0        1      5
#           RESSO_mean   1    1      1       1        0        1      5
#       kp_sqe_encoded   1    1      1       1        1        0      5
#  subcount_total_mean   1    1      1       1        1        0      5
#          MENSALIDADE   1    0      1       1        0        1      4
#  N_PREVIOUS_DOSSIERS   1    1      0       0        1        1      4
#               DURDEG   0    1      1       1        0        1      4
#               MTFINO   0    1      1       1        0        1      4
#      PRODALP_encoded   0    1      0       0        1        1      3
#             sdem_age   0    0      1       1        0        1      3
#   montenc_total_mean   0    1      1       0        1        0      3
#  sdem_SITFAM_encoded   0    0      0       1        0        1      2
#        AGFIN_encoded   0    0      0       0        1        1      2
#  MODCONTACTO_encoded   1    0      0       0        1        0      2
#           NBENF_mean   1    0      0       0        1        0      2
#    PAGAMENTO_encoded   1    0      0       0        1        0      2
#             is_risky   0    0      0       0        1        0      1
#                 SREC   0    1      0       0        0        0      1
#         POLE_encoded   1    0      0       0        0        0      1
#        ks_score_tier   0    0      0       0        0        0      0
#    montabatv_cl_mean   0    0      0       0        0        0      0
# montabatv_total_mean   0    0      0       0        0        0      0
#     montvenc_cl_mean   0    0      0       0        0        0      0
#    HIGH_RISK_CURRENT   0    0      0       0        0        0      0
#
# -> Final features (>=3/6 votes): 16
# ['previous_churn_rate', 'dividas_total_mean', 'dividas_cl_mean', 'delay_sum', 'active_credit_ratio', 'count_cl_mean', 'RESSO_mean', 'kp_sqe_encoded', 'subcount_total_mean', 'MENSALIDADE', 'N_PREVIOUS_DOSSIERS', 'DURDEG', 'MTFINO', 'PRODALP_encoded', 'sdem_age', 'montenc_total_mean']

# %% [markdown]
# As written in the output above, we decided to keep every feature that got a rank equal or higher than 3.
#
# However, since we saw high correlations in filter methods, we reduced the 16 results to 14, removing 'MTFINO' and 'N_PREVIOUS_DOSSIERS'.

# %%
best_features = ['previous_churn_rate', 'dividas_total_mean', 'dividas_cl_mean', 'delay_sum', 'active_credit_ratio',
                 'kp_sqe_encoded', 'subcount_total_mean', 'count_cl_mean', 'RESSO_mean', 'MENSALIDADE', 
                 'DURDEG', 'montenc_total_mean', 'sdem_age', 'PRODALP_encoded']

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# # 5. Kaplan-Meier Survival Curve
#
# </a>

# %%
kmf = KaplanMeierFitter()

plt.figure(figsize=(8,6))

for label, group in train_data.groupby(train_data['N_PREVIOUS_DOSSIERS'] > 0):
    
    label_name = "Returning clients" if label else "First dossier"
    
    kmf.fit(durations=group['duration'],
            event_observed=group['event'],
            label=label_name)
    
    kmf.plot_survival_function()

plt.title("Survival by Client History")
plt.xlabel("Days since dossier creation")
plt.ylabel("Probability of not churning")

plt.show()

# %% [markdown]
# In the plot above, we can see a clear diference in the probability of not churning for first time clients (first dossiers from every client) and returning clients (second or higher dossier for every client).
#
# This tells us that, although the clients are returning they tend to churn the more times they make business with the company.

# %% [markdown]
# <a class="anchor" id="1.1 Import Libraries">
#
# # 6. Model
#
# </a>

# %% [markdown]
# In this chapter, we will train both XGBoost and XGBoost Survival on our final dataset.
#
# We chose to use XGBoost as our main predictive model to predict churn since it performs well on structured tabular data, handles non-linear relationships effectively, and usually offers strong predictive performance in business problems such as churn prediction.
#
# We chose to use XGBoost Survival to predict the time to churn since it goes beyond the binary prediction and provides a time-to-event perspective.
#
# After the initial runs, we optimized both models using RandomizedSearchCV and a random parameter search.

# %% [markdown]
# ## 6.1 Baseline Benchmarking

# %%
neg, pos = (y_train == 0).sum(), (y_train == 1).sum()

# XGBoost Baseline 
xgb_base = XGBClassifier(
    n_estimators=300, max_depth=4, learning_rate=0.05,
    subsample=0.8, colsample_bytree=0.8,
    scale_pos_weight=neg/pos, random_state=42, n_jobs=-1, eval_metric='logloss'
)
xgb_base.fit(X_train[best_features], y_train,
             eval_set=[(X_val[best_features], y_val)], verbose=False)

y_prob_base  = xgb_base.predict_proba(X_val[best_features])[:, 1]
y_pred_base  = xgb_base.predict(X_val[best_features])
xgb_roc_base = roc_auc_score(y_val, y_prob_base)
xgb_pr_base  = average_precision_score(y_val, y_prob_base)
print(f'XGBoost Baseline — ROC-AUC: {xgb_roc_base:.4f} | PR-AUC: {xgb_pr_base:.4f}')
print(classification_report(y_val, y_pred_base))

# XGBoost Survival Baseline
train_surv = pd.concat([X_train[best_features], train_data[['duration','event']]], axis=1)
val_surv   = pd.concat([X_val[best_features],   val_data[['duration','event']]],   axis=1)
y_train_surv = Surv.from_dataframe(event='event', time='duration', data=train_surv)
y_val_surv   = Surv.from_dataframe(event='event', time='duration', data=val_surv)

time_bins_base = np.percentile(train_data['duration'], np.linspace(5, 95, 20))
xgbse_base_model = XGBSEKaplanNeighbors(
    {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.1, 'subsample': 0.8},
    n_neighbors=30
)
xgbse_base_model.fit(X_train[best_features], y_train_surv, time_bins=time_bins_base)
surv_val_base     = xgbse_base_model.predict(X_val[best_features])
risk_scores_base  = -surv_val_base.mean(axis=1)
xgbse_cindex_base = concordance_index_censored(
    y_val_surv['event'], y_val_surv['duration'], risk_scores_base
)[0]
print(f'XGBoost Survival Baseline — C-index: {xgbse_cindex_base:.4f}')

# Summary Table 
baseline_results = pd.DataFrame({
    'Model'   : ['XGBoost', 'XGBoost Survival'],
    'Metric'  : ['ROC-AUC', 'C-index'],
    'Baseline': [xgb_roc_base, xgbse_cindex_base]
})
print('\n=== BASELINE BENCHMARKING ===')
print(baseline_results.to_string(index=False))
# Out:
# XGBoost Baseline — ROC-AUC: 0.7389 | PR-AUC: 0.8925
#               precision    recall  f1-score   support
#
#            0       0.33      0.79      0.46      3063
#            1       0.89      0.53      0.66     10465
#
#     accuracy                           0.59     13528
#    macro avg       0.61      0.66      0.56     13528
# weighted avg       0.77      0.59      0.62     13528
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:37:05] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
# XGBoost Survival Baseline — C-index: 0.7404
#
# === BASELINE BENCHMARKING ===
#            Model  Metric  Baseline
#          XGBoost ROC-AUC  0.738912
# XGBoost Survival C-index  0.740431

# %% [markdown]
# **Baseline Benchmarking Analysis:** The baseline shows the performance of the 2 models with default parameters and the 14 selected features. XGBoost showed a ROC-AUC of 0.7389, followed by XGBoost Survival (C-index: 0.74). It's important to note that XGBoost Survival uses the C-index (survival metric) and are not directly comparable to XGBoost. These values are the starting point.

# %% [markdown]
# ## 6.2 Hyperparameter Tuning

# %%
# XGBoost — RandomizedSearchCV with PredefinedSplit (1 fold = temporal split)
split_idx = [-1]*len(X_train[best_features]) + [0]*len(X_val[best_features])
ps        = PredefinedSplit(split_idx)
X_search  = pd.concat([X_train[best_features], X_val[best_features]], ignore_index=True)
y_search  = pd.concat([y_train, y_val], ignore_index=True)

xgb_params = {
    'n_estimators'     : randint(100, 500),
    'max_depth'        : randint(3, 8),
    'learning_rate'    : uniform(0.01, 0.2),
    'subsample'        : uniform(0.6, 0.4),
    'colsample_bytree' : uniform(0.6, 0.4),
    'min_child_weight' : randint(1, 10),
    'gamma'            : uniform(0, 0.5),
}

xgb_search = RandomizedSearchCV(
    XGBClassifier(scale_pos_weight=neg/pos, random_state=42, n_jobs=-1, eval_metric='logloss'),
    xgb_params, n_iter=50, cv=ps, scoring='roc_auc', random_state=42, verbose=1, n_jobs=1
)
xgb_search.fit(X_search, y_search)
print(f"XGBoost best ROC-AUC: {xgb_search.best_score_:.4f}")
print(f"Best params: {xgb_search.best_params_}")
# Out:
# Fitting 1 folds for each of 50 candidates, totalling 50 fits
# XGBoost best ROC-AUC: 0.7456
# Best params: {'colsample_bytree': np.float64(0.8073318609454947), 'gamma': np.float64(0.4386865359639777), 'learning_rate': np.float64(0.1581537235508409), 'max_depth': 3, 'min_child_weight': 9, 'n_estimators': 398, 'subsample': np.float64(0.8835643987640474)}

# %% [markdown]
# We computed the cell above to determine the best parameters for XGBoost.

# %%
# XGBoost Survival — Random Search (20 iterations)
N_ITER = 20
random.seed(42)

def sample_xgbse_params():
    return {
        'n_estimators'    : random.choice([100, 200, 300, 400]),
        'max_depth'       : random.choice([3, 4, 5, 6, 7]),
        'learning_rate'   : round(random.uniform(0.01, 0.3), 4),
        'subsample'       : round(random.uniform(0.6, 1.0), 2),
        'colsample_bytree': round(random.uniform(0.6, 1.0), 2),
    }

time_bins = np.percentile(train_data['duration'], np.linspace(5, 95, 20))
print(f'xgbse random search: {N_ITER} iterations')

best_xgbse_score, best_xgbse_params, best_xgbse_n_neighbors = 0, {}, 30
t0 = time.time()

for i in range(1, N_ITER + 1):
    t_iter  = time.time()
    xgb_p   = sample_xgbse_params()
    n_nb    = random.choice([20, 30, 50])
    model   = XGBSEKaplanNeighbors(xgb_p, n_neighbors=n_nb)
    model.fit(X_train[best_features], y_train_surv, time_bins=time_bins)
    surv_v  = model.predict(X_val[best_features])
    risk_v  = -surv_v.mean(axis=1)
    score   = concordance_index_censored(y_val_surv['event'], y_val_surv['duration'], risk_v)[0]
    elapsed = time.time() - t_iter
    print(f'  [{i}/{N_ITER}] C-index={score:.4f}  ({elapsed:.0f}s)  n_neighbors={n_nb}  {xgb_p}')
    if score > best_xgbse_score:
        best_xgbse_score, best_xgbse_params, best_xgbse_n_neighbors = score, xgb_p, n_nb

total = time.time() - t0
print(f'\nxgbse best C-index: {best_xgbse_score:.4f}')
print(f'Best XGB Survival params:    {best_xgbse_params}')
print(f'Best n_neighbors:   {best_xgbse_n_neighbors}')
print(f'Total search time:  {total/60:.1f} min')
# Out:
# xgbse random search: 20 iterations
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:38:28] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [1/20] C-index=0.7323  (27s)  n_neighbors=20  {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.225, 'subsample': 0.7, 'colsample_bytree': 0.66, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:38:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [2/20] C-index=0.7627  (50s)  n_neighbors=50  {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1324, 'subsample': 0.61, 'colsample_bytree': 0.69, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:39:44] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [3/20] C-index=0.7566  (42s)  n_neighbors=20  {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.0677, 'subsample': 0.86, 'colsample_bytree': 0.82, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:40:27] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [4/20] C-index=0.7563  (39s)  n_neighbors=20  {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0907, 'subsample': 0.95, 'colsample_bytree': 0.9, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:41:06] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [5/20] C-index=0.7382  (30s)  n_neighbors=20  {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.0906, 'subsample': 0.69, 'colsample_bytree': 0.91, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:41:36] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [6/20] C-index=0.7499  (35s)  n_neighbors=20  {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.038, 'subsample': 0.94, 'colsample_bytree': 0.84, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:42:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [7/20] C-index=0.7625  (51s)  n_neighbors=30  {'n_estimators': 400, 'max_depth': 7, 'learning_rate': 0.0462, 'subsample': 0.97, 'colsample_bytree': 0.63, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:43:02] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [8/20] C-index=0.7577  (37s)  n_neighbors=30  {'n_estimators': 300, 'max_depth': 7, 'learning_rate': 0.0658, 'subsample': 0.63, 'colsample_bytree': 0.86, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:43:39] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [9/20] C-index=0.7552  (54s)  n_neighbors=30  {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.2613, 'subsample': 0.75, 'colsample_bytree': 0.78, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:44:33] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [10/20] C-index=0.7498  (41s)  n_neighbors=50  {'n_estimators': 200, 'max_depth': 5, 'learning_rate': 0.113, 'subsample': 0.87, 'colsample_bytree': 0.88, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:45:14] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [11/20] C-index=0.7633  (58s)  n_neighbors=30  {'n_estimators': 100, 'max_depth': 7, 'learning_rate': 0.1941, 'subsample': 0.81, 'colsample_bytree': 0.7, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:46:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [12/20] C-index=0.7598  (59s)  n_neighbors=50  {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.297, 'subsample': 0.86, 'colsample_bytree': 0.82, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:47:11] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [13/20] C-index=0.7069  (14s)  n_neighbors=30  {'n_estimators': 300, 'max_depth': 3, 'learning_rate': 0.0764, 'subsample': 0.61, 'colsample_bytree': 0.73, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:47:25] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [14/20] C-index=0.7524  (38s)  n_neighbors=20  {'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.2748, 'subsample': 0.83, 'colsample_bytree': 0.89, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:48:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [15/20] C-index=0.7579  (42s)  n_neighbors=20  {'n_estimators': 400, 'max_depth': 6, 'learning_rate': 0.2666, 'subsample': 0.86, 'colsample_bytree': 0.66, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:48:45] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [16/20] C-index=0.7689  (38s)  n_neighbors=50  {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.1663, 'subsample': 0.9, 'colsample_bytree': 0.77, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:49:23] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [17/20] C-index=0.7258  (19s)  n_neighbors=20  {'n_estimators': 400, 'max_depth': 5, 'learning_rate': 0.0736, 'subsample': 1.0, 'colsample_bytree': 0.8, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:49:42] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [18/20] C-index=0.6964  (9s)  n_neighbors=50  {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.0543, 'subsample': 0.66, 'colsample_bytree': 0.87, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:49:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [19/20] C-index=0.7618  (41s)  n_neighbors=50  {'n_estimators': 100, 'max_depth': 6, 'learning_rate': 0.1207, 'subsample': 1.0, 'colsample_bytree': 0.81, 'objective': 'survival:aft'}
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [20:50:32] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
#   [20/20] C-index=0.7365  (33s)  n_neighbors=50  {'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2077, 'subsample': 0.81, 'colsample_bytree': 0.71, 'objective': 'survival:aft'}
#
# xgbse best C-index: 0.7689
# Best XGB Survival params:    {'n_estimators': 200, 'max_depth': 7, 'learning_rate': 0.1663, 'subsample': 0.9, 'colsample_bytree': 0.77, 'objective': 'survival:aft'}
# Best n_neighbors:   50
# Total search time:  12.6 min

# %%
best_XGBse_params = best_xgbse_params
Best_n_neighbors = best_xgbse_n_neighbors

# %% [markdown]
# We computed the cell above to determine the best parameters for XGBoost Survival.

# %% [markdown]
# ## 6.3 Final Benchmarking

# %%
# XGBoost Final
xgb_final     = xgb_search.best_estimator_
y_prob_final  = xgb_final.predict_proba(X_val[best_features])[:, 1]
y_pred_final  = xgb_final.predict(X_val[best_features])
xgb_roc_final = roc_auc_score(y_val, y_prob_final)
xgb_pr_final  = average_precision_score(y_val, y_prob_final)

print('=== XGBoost Final ===')
print(classification_report(y_val, y_pred_final))
print(f'ROC-AUC: {xgb_roc_final:.4f} | PR-AUC: {xgb_pr_final:.4f}')

precision, recall, _ = precision_recall_curve(y_val, y_prob_final)
plt.figure(figsize=(8, 5))
plt.plot(recall, precision, color='darkorange', lw=2, label=f'PR-AUC = {xgb_pr_final:.3f}')
plt.xlabel('Recall'); plt.ylabel('Precision')
plt.title('Precision-Recall Curve — XGBoost Tuned')
plt.legend(); plt.grid(True, linestyle='--', alpha=0.7); plt.tight_layout(); plt.show()

# XGBoost Survival (xgbse) Final
time_bins    = np.percentile(train_data['duration'], np.linspace(5, 95, 20))
xgbse_final  = XGBSEKaplanNeighbors(best_XGBse_params, n_neighbors=Best_n_neighbors)
xgbse_final.fit(X_train[best_features], y_train_surv, time_bins=time_bins)

surv_val        = xgbse_final.predict(X_val[best_features])
risk_scores_val = -surv_val.mean(axis=1)
xgbse_cindex_final = concordance_index_censored(
    y_val_surv['event'], y_val_surv['duration'], risk_scores_val
)[0]
print(f'\nXGBoost Survival Final — C-index: {xgbse_cindex_final:.4f}')

# Overfitting check
y_prob_train_final = xgb_final.predict_proba(X_train[best_features])[:, 1]
xgb_roc_train      = roc_auc_score(y_train, y_prob_train_final)

surv_train         = xgbse_final.predict(X_train[best_features])
risk_scores_train  = -surv_train.mean(axis=1)
xgbse_cindex_train = concordance_index_censored(
    y_train_surv['event'], y_train_surv['duration'], risk_scores_train
)[0]

print(f'\n=== OVERFITTING CHECK (Train vs Val) ===')
print(f'XGBoost          — Train: {xgb_roc_train:.4f}  | Val: {xgb_roc_final:.4f}  | Gap: {xgb_roc_train - xgb_roc_final:.4f}')
print(f'XGBoost Survival — Train: {xgbse_cindex_train:.4f}  | Val: {xgbse_cindex_final:.4f}  | Gap: {xgbse_cindex_train - xgbse_cindex_final:.4f}')

# Comparative Table 
comparison = pd.DataFrame({
    'Model'   : ['XGBoost', 'XGBoost Survival'],
    'Metric'  : ['ROC-AUC', 'C-index'],
    'Baseline': [xgb_roc_base, xgbse_cindex_base],
    'Tuned'   : [xgb_roc_final, xgbse_cindex_final],
})
comparison['Gain'] = (comparison['Tuned'] - comparison['Baseline']).round(4)
print('\n=== BENCHMARKING: BASELINE vs TUNED ===')
print(comparison.to_string(index=False))
# Out:
# === XGBoost Final ===
#               precision    recall  f1-score   support
#
#            0       0.36      0.86      0.50      3063
#            1       0.93      0.55      0.69     10465
#
#     accuracy                           0.62     13528
#    macro avg       0.64      0.70      0.60     13528
# weighted avg       0.80      0.62      0.65     13528
#
# ROC-AUC: 0.8068 | PR-AUC: 0.9316
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgboost\training.py:200: UserWarning: [22:02:08] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "n_estimators" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
# XGBoost Survival Final — C-index: 0.7689
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
# === OVERFITTING CHECK (Train vs Val) ===
# XGBoost          — Train: 0.8942  | Val: 0.8068  | Gap: 0.0874
# XGBoost Survival — Train: 0.7955  | Val: 0.7689  | Gap: 0.0266
#
# === BENCHMARKING: BASELINE vs TUNED ===
#            Model  Metric  Baseline    Tuned   Gain
#          XGBoost ROC-AUC  0.738912 0.806814 0.0679
# XGBoost Survival C-index  0.740431 0.768896 0.0285

# %% [markdown]
# **Final Benchmarking Analysis:** After tuning, XGBoost improved significantly, from ROC-AUC 0.7389, to **0.8068** (+0.0679). XGBoost Survival also improved, from 0.740462 to **0.762512** (+0.0220). The Train vs Val gap above indicates whether there is overfitting — values below 0.05 are normal, above 0.10 require attention. **Conclusion:** XGBoost to classify who will churn and XGBoost Survival to understand when.

# %% [markdown]
# ## 6.4 SHAP — XGBoost Model Explainability

# %%
explainer   = shap.TreeExplainer(xgb_final)
shap_values = explainer.shap_values(X_val[best_features])

plt.figure()
shap.summary_plot(shap_values, X_val[best_features], plot_type="bar", max_display = 3, show=False)
plt.title("SHAP — Global Feature Importance")
plt.tight_layout()
plt.show()

plt.figure()
shap.summary_plot(shap_values, X_val[best_features], max_display = 3, show=False)
plt.title("SHAP — Per-Observation Impact (Beeswarm)")
plt.tight_layout()
plt.show()

# %% [markdown]
# In the plots above, we can see that the features 'dividas_cl_mean', 'delay_sum' and 'active_credit_ratio' were the most important features in predicting whether the dossier would result in a churn or not.

# %% [markdown]
# **SHAP Analysis:** SHAP explains how XGBoost makes each individual decision.
#
# The **bar chart** (global importance) shows the features that most influence predictions on average.
#
# The **beeswarm plot** is richer — each dot is a client. Dots to the right (positive SHAP) increase that client's churn risk; to the left they decrease it. The color indicates the feature value (red=high, blue=low). E.g.: red dots on the right for previous_churn_rate mean that clients with a churn history have a higher probability of leaving again — an actionable insight.

# %%
explainer_surv   = shap.TreeExplainer(xgbse_final.feature_extractor.bst)
shap_values_surv = explainer_surv.shap_values(X_val[best_features])

plt.figure()
shap.summary_plot(shap_values_surv, X_val[best_features], plot_type="bar", max_display = 3, show=False)
plt.title("SHAP — Global Feature Importance")
plt.tight_layout()
plt.show()

plt.figure()
shap.summary_plot(shap_values_surv, X_val[best_features], max_display = 3, show=False)
plt.title("SHAP — Per-Observation Impact (Beeswarm)")
plt.tight_layout()
plt.show()

# %% [markdown]
# In the plots above, we can see that the features 'previous_churn_rate', 'DURDEG' and 'delay_sum' were the most important features in predicting how long the dossiers would take to churn.

# %% [markdown]
# ## 6.5 Survival Analysis — Business Insights

# %%
# Survival curves by risk group (Kaplan-Meier)
# risk_scores_val computed in the benchmarking cell above
val_surv_plot = val_surv.copy()
val_surv_plot['risk_group'] = pd.qcut(risk_scores_val, q=3,
                                        labels=['Low Risk', 'Medium Risk', 'High Risk'])

plt.figure(figsize=(10, 6))
kmf = KaplanMeierFitter()
colors = {'Low Risk': 'green', 'Medium Risk': 'orange', 'High Risk': 'red'}

for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    mask = val_surv_plot['risk_group'] == group
    kmf.fit(val_surv_plot.loc[mask, 'duration'], val_surv_plot.loc[mask, 'event'], label=group)
    kmf.plot_survival_function(color=colors[group], ci_show=True)

plt.title('Survival Curves by Risk Group (Kaplan-Meier)')
plt.xlabel('Contract Duration (days)')
plt.ylabel('Probability of Not Churning')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

print('=== MEDIAN TIME TO CHURN BY GROUP ===')
for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    mask = val_surv_plot['risk_group'] == group
    kmf.fit(val_surv_plot.loc[mask, 'duration'], val_surv_plot.loc[mask, 'event'])
    median = kmf.median_survival_time_
    print(f'  {group}: {median:.0f} days ({median/30:.1f} months)')
# Out:
# === MEDIAN TIME TO CHURN BY GROUP ===
#   Low Risk: 1084 days (36.1 months)
#   Medium Risk: 994 days (33.1 months)
#   High Risk: 1103 days (36.8 months)

# %%
# Individual XGBoost Survival curves — 3 client profiles
low_idx  = val_surv_plot[val_surv_plot['risk_group'] == 'Low Risk'].index[0]
med_idx  = val_surv_plot[val_surv_plot['risk_group'] == 'Medium Risk'].index[0]
high_idx = val_surv_plot[val_surv_plot['risk_group'] == 'High Risk'].index[0]

sample_idx    = [low_idx, med_idx, high_idx]
sample_labels = ['Low Risk Client', 'Medium Risk Client', 'High Risk Client']
sample_colors = ['green', 'orange', 'red']

surv_sample = xgbse_final.predict(X_val[best_features].loc[sample_idx])
times       = surv_sample.columns.values

plt.figure(figsize=(10, 6))
for i, (label, color) in enumerate(zip(sample_labels, sample_colors)):
    plt.step(times, surv_sample.iloc[i].values, where='post',
             label=label, linewidth=2.5, color=color)

plt.title('Individual Survival Curves (XGBoost Survival) — Client Profiles')
plt.xlabel('Contract Duration (days)')
plt.ylabel('Probability of Not Churning')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values

# %%
# Average survival curve + hazard rate — intervention window
sample_size    = 500
sample_val_idx = X_val[best_features].sample(sample_size, random_state=42).index

surv_df_all = xgbse_final.predict(X_val[best_features].loc[sample_val_idx])
times       = surv_df_all.columns.values
avg_surv    = surv_df_all.values.mean(axis=0)

delta_s       = -np.diff(avg_surv)
hazard_approx = delta_s / (avg_surv[:-1] + 1e-9)
hazard_times  = times[:-1]
hazard_smooth = uniform_filter1d(hazard_approx, size=max(1, len(hazard_approx)//10))

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].plot(times, avg_surv, color='teal', linewidth=2)
axes[0].set_title('Average Survival Curve')
axes[0].set_xlabel('Contract Duration (days)')
axes[0].set_ylabel('P(Not Churning)')
axes[0].grid(True, linestyle='--', alpha=0.5)

axes[1].plot(hazard_times, hazard_smooth, color='crimson', linewidth=2)
peak_idx  = np.argmax(hazard_smooth)
peak_time = hazard_times[peak_idx]
axes[1].axvline(x=peak_time, color='red', linestyle='--', alpha=0.8)
axes[1].annotate(
    f'Peak: day {peak_time:.0f} ({peak_time/30:.0f} months)',
    xy=(peak_time, hazard_smooth[peak_idx]),
    xytext=(peak_time + max(30, peak_time*0.2), hazard_smooth[peak_idx] * 0.8),
    arrowprops=dict(arrowstyle='->', color='red'), fontsize=11, color='red'
)
axes[1].set_title('Instantaneous Churn Risk Over Contract Duration')
axes[1].set_xlabel('Contract Duration (days)')
axes[1].set_ylabel('Hazard Rate')
axes[1].grid(True, linestyle='--', alpha=0.5)

plt.suptitle('Temporal Analysis — Intervention Window for Retention', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

print(f'\n→ RECOMMENDATION: Intervene BEFORE day {peak_time:.0f} ({peak_time/30:.0f} months of contract)')
# Out:
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
# → RECOMMENDATION: Intervene BEFORE day 2721 (91 months of contract)

# %%
# Hazard Rate by Risk Group — reuses surv_df_all from previous cell
sample_groups = val_surv_plot.loc[sample_val_idx, 'risk_group'].values
surv_by_group = {}
for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    mask_idx = [i for i, g in enumerate(sample_groups) if g == group]
    surv_by_group[group] = surv_df_all.iloc[mask_idx]

fig, axes = plt.subplots(1, 2, figsize=(18, 7))
colors_grp = {'Low Risk': 'green', 'Medium Risk': 'orange', 'High Risk': 'red'}

print('=== INTERVENTION WINDOW BY GROUP ===')
for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    surv_df_grp  = surv_by_group[group]
    times_grp    = surv_df_grp.columns.values
    avg_surv_grp = surv_df_grp.values.mean(axis=0)

    axes[0].plot(times_grp, avg_surv_grp, color=colors_grp[group], linewidth=2.5, label=group)

    delta_s_grp  = -np.diff(avg_surv_grp)
    hazard_grp   = delta_s_grp / (avg_surv_grp[:-1] + 1e-9)
    h_times_grp  = times_grp[:-1]
    h_smooth_grp = uniform_filter1d(hazard_grp, size=max(1, len(hazard_grp)//10))
    axes[1].plot(h_times_grp, h_smooth_grp, color=colors_grp[group], linewidth=2.5, label=group)

    peak_idx_grp = np.argmax(h_smooth_grp)
    peak_t_grp   = h_times_grp[peak_idx_grp]
    axes[1].axvline(x=peak_t_grp, color=colors_grp[group], linestyle='--', alpha=0.6)
    axes[1].annotate(
        f'{group}: {peak_t_grp/30:.0f}m',
        xy=(peak_t_grp, h_smooth_grp[peak_idx_grp]),
        xytext=(peak_t_grp + 200, h_smooth_grp[peak_idx_grp] * 1.05),
        fontsize=9, color=colors_grp[group], fontweight='bold'
    )
    intervene = max(1, round(peak_t_grp/30) - 2)
    print(f'  {group}: peak at day {peak_t_grp:.0f} ({peak_t_grp/30:.1f} months) -> intervene before month {intervene}')

axes[0].set_title('Average Survival Curve by Risk Group')
axes[0].set_xlabel('Contract Duration (days)')
axes[0].set_ylabel('P(Not Churning)')
axes[0].legend(); axes[0].grid(True, linestyle='--', alpha=0.5)

axes[1].set_title('Hazard Rate by Risk Group')
axes[1].set_xlabel('Contract Duration (days)')
axes[1].set_ylabel('Hazard Rate')
axes[1].legend(); axes[1].grid(True, linestyle='--', alpha=0.5)

plt.suptitle('Differentiated Intervention Window by Risk Group', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
# Out:
# === INTERVENTION WINDOW BY GROUP ===
#   Low Risk: peak at day 2409 (80.3 months) -> intervene before month 78
#   Medium Risk: peak at day 2409 (80.3 months) -> intervene before month 78
#   High Risk: peak at day 2409 (80.3 months) -> intervene before month 78

# %%
fig, ax = plt.subplots(figsize=(14, 6))
colors_grp  = {'Low Risk': 'green', 'Medium Risk': 'orange', 'High Risk': 'red'}
churn_tables = {}

for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    surv_df_grp  = surv_by_group[group]
    times_grp    = surv_df_grp.columns.values
    avg_surv_grp = surv_df_grp.values.mean(axis=0)

    max_months        = int(times_grp[-1] / 30)
    months            = np.arange(1, max_months + 1)
    surv_monthly      = np.interp(months * 30, times_grp, avg_surv_grp)
    surv_with_start   = np.concatenate([[1.0], surv_monthly])
    churn_pct         = np.diff(-surv_with_start) * 100

    ax.plot(months, churn_pct, color=colors_grp[group], linewidth=2, label=group)
    churn_tables[group] = pd.Series(churn_pct, index=months)

ax.set_title('% of Dossiers Churning per Month — by Risk Group')
ax.set_xlabel('Contract Month')
ax.set_ylabel('% of Dossiers Churning That Month')
ax.legend(); ax.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout(); plt.show()

periodos = [(1,3,'Month 1-3'), (4,6,'Month 4-6'), (7,9,'Month 7-9'), (10,12,'Month 10-12'),
            (13,18,'Month 13-18'), (19,24,'Month 19-24'), (25,36,'Month 25-36'),
            (37,48,'Month 37-48'), (49,60,'Month 49-60')]

rows = []
for start, end, label in periodos:
    row = {'Period': label}
    for group in ['High Risk', 'Medium Risk', 'Low Risk']:
        s     = churn_tables[group]
        valid = s[(s.index >= start) & (s.index <= end)]
        row[group] = f'{valid.sum():.1f}%' if len(valid) > 0 else '—'
    rows.append(row)

print('=== CUMULATIVE % OF DOSSIERS CHURNING BY PERIOD AND GROUP ===')
print(pd.DataFrame(rows).to_string(index=False))
# Out:
# === CUMULATIVE % OF DOSSIERS CHURNING BY PERIOD AND GROUP ===
#      Period High Risk Medium Risk Low Risk
#   Month 1-3      3.5%        4.5%     1.1%
#   Month 4-6      2.0%        1.4%     1.2%
#   Month 7-9      4.1%        3.1%     1.8%
# Month 10-12      5.7%        6.5%     3.4%
# Month 13-18     13.5%       12.7%     9.4%
# Month 19-24     12.9%        8.0%    10.2%
# Month 25-36     25.3%       12.4%    24.4%
# Month 37-48     10.7%        9.2%    14.7%
# Month 49-60      4.9%       10.4%     6.5%

# %% [markdown]
# ## 6.6 Active Portfolio — Test Set Analysis
#
# Application of both trained models to the active contract portfolio (no observed outcomes yet).
# - **XGBoost Classifier**: overall churn risk distribution
# - **XGBoost Survival**: temporal analysis — when clients are expected to churn

# %%
# XGBoost Classifier — Active Portfolio (totals)
y_prob_test = xgb_final.predict_proba(X_test[best_features])[:, 1]

plt.figure(figsize=(9, 5))
plt.hist(y_prob_test, bins=40, color="steelblue", edgecolor="white", alpha=0.85)
plt.axvline(0.3, color="orange", linestyle="--", linewidth=1.5, label="Medium threshold (0.3)")
plt.axvline(0.6, color="red",    linestyle="--", linewidth=1.5, label="High threshold (0.6)")
plt.title("Distribution of Churn Probability — Active Portfolio (XGBoost)")
plt.xlabel("Predicted Churn Probability")
plt.ylabel("Number of Contracts")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.tight_layout()
plt.show()

high   = (y_prob_test >= 0.6).sum()
medium = ((y_prob_test >= 0.3) & (y_prob_test < 0.6)).sum()
low    = (y_prob_test < 0.3).sum()
total  = len(y_prob_test)
print(f"Total active contracts : {total}")
print(f"High Risk   (>=0.6)    : {high:>4}  ({high/total*100:.1f}%)")
print(f"Medium Risk (0.3-0.6)  : {medium:>4}  ({medium/total*100:.1f}%)")
print(f"Low Risk    (<0.3)     : {low:>4}  ({low/total*100:.1f}%)")
print(f"Mean churn probability : {y_prob_test.mean():.3f}")
# Out:
# Total active contracts : 108954
# High Risk   (>=0.6)    : 51152  (46.9%)
# Medium Risk (0.3-0.6)  : 44986  (41.3%)
# Low Risk    (<0.3)     : 12816  (11.8%)
# Mean churn probability : 0.580

# %%
# XGBoost Survival — Average survival curve + hazard (whole portfolio)
surv_test         = xgbse_final.predict(X_test[best_features])
surv_test.index   = X_test[best_features].index
risk_scores_test  = -surv_test.mean(axis=1)
risk_groups_test  = pd.qcut(risk_scores_test, q=3,
                             labels=["Low Risk", "Medium Risk", "High Risk"])

sample_test_idx   = X_test[best_features].sample(min(500, len(X_test)), random_state=42).index
surv_df_test_avg  = xgbse_final.predict(X_test[best_features].loc[sample_test_idx])
times_test        = surv_df_test_avg.columns.values
avg_surv_test     = surv_df_test_avg.values.mean(axis=0)

delta_s       = -np.diff(avg_surv_test)
hazard_approx = delta_s / (avg_surv_test[:-1] + 1e-9)
hazard_times  = times_test[:-1]
hazard_smooth = uniform_filter1d(hazard_approx, size=max(1, len(hazard_approx)//10))

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

axes[0].plot(times_test, avg_surv_test, color="teal", linewidth=2)
axes[0].set_title("Average Survival Curve — Active Portfolio")
axes[0].set_xlabel("Contract Duration (days)")
axes[0].set_ylabel("P(Not Churning)")
axes[0].grid(True, linestyle="--", alpha=0.5)

peak_idx  = np.argmax(hazard_smooth)
peak_time = hazard_times[peak_idx]
axes[1].plot(hazard_times, hazard_smooth, color="crimson", linewidth=2)
axes[1].axvline(x=peak_time, color="red", linestyle="--", alpha=0.8)
axes[1].annotate(
    f"Peak: day {peak_time:.0f} ({peak_time/30:.0f} months)",
    xy=(peak_time, hazard_smooth[peak_idx]),
    xytext=(peak_time + max(30, peak_time*0.2), hazard_smooth[peak_idx]*0.8),
    arrowprops=dict(arrowstyle="->", color="red"), fontsize=11, color="red"
)
axes[1].set_title("Churn Risk Over Contract Duration — Active Portfolio")
axes[1].set_xlabel("Contract Duration (days)")
axes[1].set_ylabel("Hazard Rate")
axes[1].grid(True, linestyle="--", alpha=0.5)

plt.suptitle("Active Portfolio — Average Temporal Risk (XGBoost Survival)",
             fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
print(f"Peak churn risk: day {peak_time:.0f} ({peak_time/30:.0f} months)")
# Out:
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values
# Peak churn risk: day 2721 (91 months)

# %%
# Temporal survival analysis — active portfolio
sample_test_idx    = X_test[best_features].sample(min(500, len(X_test)), random_state=42).index
surv_df_test       = xgbse_final.predict(X_test[best_features].loc[sample_test_idx])
sample_test_groups = risk_groups_test.loc[sample_test_idx].values
times_test         = surv_df_test.columns.values

surv_by_group_test = {}
for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    mask_idx = [i for i, g in enumerate(sample_test_groups) if g == group]
    surv_by_group_test[group] = surv_df_test.iloc[mask_idx]

fig, axes = plt.subplots(1, 2, figsize=(18, 7))
colors_grp    = {'Low Risk': 'green', 'Medium Risk': 'orange', 'High Risk': 'red'}
churn_tables_test = {}

for group in ['Low Risk', 'Medium Risk', 'High Risk']:
    surv_df_grp  = surv_by_group_test[group]
    avg_surv_grp = surv_df_grp.values.mean(axis=0)
    axes[0].plot(times_test, avg_surv_grp, color=colors_grp[group], linewidth=2.5, label=group)

    max_months        = int(times_test[-1] / 30)
    months            = np.arange(1, max_months + 1)
    surv_monthly      = np.interp(months * 30, times_test, avg_surv_grp)
    surv_with_start   = np.concatenate([[1.0], surv_monthly])
    churn_pct         = np.diff(-surv_with_start) * 100
    axes[1].plot(months, churn_pct, color=colors_grp[group], linewidth=2, label=group)
    churn_tables_test[group] = pd.Series(churn_pct, index=months)

axes[0].set_title('Survival Curves — Active Portfolio')
axes[0].set_xlabel('Contract Duration (days)'); axes[0].set_ylabel('P(Not Churning)')
axes[0].legend(); axes[0].grid(True, linestyle='--', alpha=0.5)

axes[1].set_title('% of Active Contracts Churning per Month')
axes[1].set_xlabel('Contract Month'); axes[1].set_ylabel('% Churning That Month')
axes[1].legend(); axes[1].grid(True, linestyle='--', alpha=0.5)

plt.suptitle('Active Portfolio — Temporal Risk Analysis (XGBoost Survival)',
             fontsize=14, fontweight='bold')
plt.tight_layout(); plt.show()
# Out:
# c:\Users\jcari\anaconda3\envs\Fall2526\Lib\site-packages\xgbse\non_parametric.py:61: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   return pd.DataFrame(C_exp).fillna(method="bfill").fillna(method="ffill").values

# %%
# Quarterly cumulative churn table — active portfolio
periodos = [(1,3,'Month 1-3'), (4,6,'Month 4-6'), (7,9,'Month 7-9'), (10,12,'Month 10-12'),
            (13,18,'Month 13-18'), (19,24,'Month 19-24'), (25,36,'Month 25-36'),
            (37,48,'Month 37-48'), (49,60,'Month 49-60')]

rows = []
for start, end, label in periodos:
    row = {'Period': label}
    for group in ['High Risk', 'Medium Risk', 'Low Risk']:
        s     = churn_tables_test[group]
        valid = s[(s.index >= start) & (s.index <= end)]
        row[group] = f'{valid.sum():.1f}%' if len(valid) > 0 else '—'
    rows.append(row)

print('=== CUMULATIVE % CHURNING BY PERIOD — ACTIVE PORTFOLIO ===')
print(pd.DataFrame(rows).to_string(index=False))
# Out:
# === CUMULATIVE % CHURNING BY PERIOD — ACTIVE PORTFOLIO ===
#      Period High Risk Medium Risk Low Risk
#   Month 1-3      9.8%        3.7%     1.6%
#   Month 4-6      4.5%        1.5%     0.4%
#   Month 7-9      8.0%        3.1%     1.0%
# Month 10-12      8.6%        3.8%     1.3%
# Month 13-18     15.2%        8.4%     2.7%
# Month 19-24     15.4%        7.6%     2.6%
# Month 25-36     21.0%       18.3%     4.9%
# Month 37-48      8.0%       22.1%     6.9%
# Month 49-60      2.7%       11.4%    17.8%
